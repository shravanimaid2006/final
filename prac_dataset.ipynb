# %%
import pandas as pd

# %%
df =pd.read_csv('chrun2.csv')
df
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 1         C002  Postpaid           45.1  South          Gold          1
# 2         C003   Prepaid            3.4   East        Silver          0
# 3         C004    Hybrid           22.3   West        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 5         C006   Prepaid            8.9  South        Bronze          0
# 6         C007  Postpaid           33.5   East        Silver          1
# 7         C008    Hybrid           18.4   West        Silver          1
# 8         C009   Prepaid            6.1  North        Bronze          0
# 9         C010  Postpaid           47.0  South          Gold          1
# 10        C011    Hybrid           20.2   East        Silver          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# ...

# %%
df.shape
# Out:
# (15, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 1         C002  Postpaid           45.1  South          Gold          1
# 2         C003   Prepaid            3.4   East        Silver          0
# 3         C004    Hybrid           22.3   West        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 5         C006   Prepaid            8.9  South        Bronze          0
# 6         C007  Postpaid           33.5   East        Silver          1
# 7         C008    Hybrid           18.4   West        Silver          1
# 8         C009   Prepaid            6.1  North        Bronze          0
# 9         C010  Postpaid           47.0  South          Gold          1
# 10        C011    Hybrid           20.2   East        Silver          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# ...

# %%
df.isnull()
# Out:
#     customer_id  plan_type  data_usage_gb  region  customer_tier  is_active  \
# 0         False      False          False   False          False      False
# 1         False      False          False   False          False      False
# 2         False      False          False   False          False      False
# 3         False      False          False   False          False      False
# 4         False      False          False   False          False      False
# 5         False      False          False   False          False      False
# 6         False      False          False   False          False      False
# 7         False      False          False   False          False      False
# 8         False      False          False   False          False      False
# 9         False      False          False   False          False      False
# 10        False      False          False   False          False      False
# ...

# %%
(df.isnull().sum())
# Out:
# customer_id                 0
# plan_type                   0
# data_usage_gb               0
# region                      0
# customer_tier               0
# is_active                   0
# complaints                  0
# last_recharge_date          0
# days_since_last_recharge    0
# avg_call_duration           0
# min_monthly_payment         0
# total_recharge_amount       0
# sms_usage                   0
# churn                       0
# dtype: int64

# %%
df.describe()
# Out:
#        data_usage_gb  is_active  complaints  days_since_last_recharge  \
# count      15.000000  15.000000   15.000000                 15.000000
# mean       23.746667   0.600000    0.466667                 14.000000
# std        19.757815   0.507093    0.516398                 10.869354
# min         2.300000   0.000000    0.000000                  1.000000
# 25%         7.500000   0.000000    0.000000                  4.500000
# 50%        18.400000   1.000000    0.000000                 12.000000
# 75%        39.300000   1.000000    1.000000                 21.500000
# max        60.400000   1.000000    1.000000                 33.000000
#
#        avg_call_duration  min_monthly_payment  total_recharge_amount  \
# count          15.000000            15.000000              15.000000
# mean            8.053333           342.333333            2886.666667
# std             4.782388           254.941637            2609.629603
# ...

# %%
df['customer_tier'].value_counts()
# Out:
# customer_tier
# Bronze      6
# Silver      4
# Gold        3
# Platinum    2
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# North    4
# South    4
# East     4
# West     3
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#   customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0        C001   Prepaid           12.5  North        Bronze          1
# 1        C002  Postpaid           45.1  South          Gold          1
# 2        C003   Prepaid            3.4   East        Silver          0
# 3        C004    Hybrid           22.3   West        Bronze          1
# 4        C005  Postpaid           55.8  North      Platinum          1
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 0           0         2025-01-12                         5               12.4
# 1           1         2025-01-01                        16                8.1
# 2           0         2024-12-28                        20                3.5
# 3           1         2025-01-10                         7               15.2
# 4           0         2025-01-14                         3                6.9
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# ...

# %%
df.tail()
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 10        C011    Hybrid           20.2   East        Silver          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# 12        C013  Postpaid           60.4  North      Platinum          1
# 13        C014    Hybrid           15.5  South          Gold          0
# 14        C015   Prepaid            2.3   East        Bronze          0
#
#     complaints last_recharge_date  days_since_last_recharge  \
# 10           1         2024-12-25                        23
# 11           0         2025-01-09                         8
# 12           0         2025-01-15                         2
# 13           1         2024-12-30                        18
# 14           1         2024-12-15                        33
#
#     avg_call_duration  min_monthly_payment  total_recharge_amount  sms_usage  \
# 10                5.7                  269                   2000          7
# ...

# %%
df.head(3)
# Out:
#   customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0        C001   Prepaid           12.5  North        Bronze          1
# 1        C002  Postpaid           45.1  South          Gold          1
# 2        C003   Prepaid            3.4   East        Silver          0
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 0           0         2025-01-12                         5               12.4
# 1           1         2025-01-01                        16                8.1
# 2           0         2024-12-28                        20                3.5
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# 0                  199                   1500         34      0
# 1                  499                   5200         12      0
# 2                  149                    900          5      1

# %%
df[['region','customer_tier','plan_type']]
# Out:
#    region customer_tier plan_type
# 0   North        Bronze   Prepaid
# 1   South          Gold  Postpaid
# 2    East        Silver   Prepaid
# 3    West        Bronze    Hybrid
# 4   North      Platinum  Postpaid
# 5   South        Bronze   Prepaid
# 6    East        Silver  Postpaid
# 7    West        Silver    Hybrid
# 8   North        Bronze   Prepaid
# 9   South          Gold  Postpaid
# 10   East        Silver    Hybrid
# 11   West        Bronze   Prepaid
# 12  North      Platinum  Postpaid
# 13  South          Gold    Hybrid
# 14   East        Bronze   Prepaid

# %%
df.loc[]
# Out:
#   Cell In[29], line 1
#     df.loc[]
#            ^
# SyntaxError: invalid syntax

# %%
df['plan_type'].value_counts()
# Out:
# plan_type
# Prepaid     6
# Postpaid    5
# Hybrid      4
# Name: count, dtype: int64

# %%
df.loc[5]
# Out:
# customer_id                       C006
# plan_type                      Prepaid
# data_usage_gb                      8.9
# region                           South
# customer_tier                   Bronze
# is_active                            0
# complaints                           1
# last_recharge_date          2024-12-20
# days_since_last_recharge            28
# avg_call_duration                  2.1
# min_monthly_payment                 99
# total_recharge_amount              400
# sms_usage                            2
# churn                                1
# Name: 5, dtype: object

# %%
df.loc[5]
# Out:
# customer_id                       C006
# plan_type                      Prepaid
# data_usage_gb                      8.9
# region                           South
# customer_tier                   Bronze
# is_active                            0
# complaints                           1
# last_recharge_date          2024-12-20
# days_since_last_recharge            28
# avg_call_duration                  2.1
# min_monthly_payment                 99
# total_recharge_amount              400
# sms_usage                            2
# churn                                1
# Name: 5, dtype: object

# %%
df.loc[5,'region' == north]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.loc[5,'region' == north]
#
# NameError: name 'north' is not defined

# %%
df.loc[df['region']=='South']
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 1         C002  Postpaid           45.1  South          Gold          1
# 5         C006   Prepaid            8.9  South        Bronze          0
# 9         C010  Postpaid           47.0  South          Gold          1
# 13        C014    Hybrid           15.5  South          Gold          0
#
#     complaints last_recharge_date  days_since_last_recharge  \
# 1            1         2025-01-01                        16
# 5            1         2024-12-20                        28
# 9            0         2025-01-13                         4
# 13           1         2024-12-30                        18
#
#     avg_call_duration  min_monthly_payment  total_recharge_amount  sms_usage  \
# 1                 8.1                  499                   5200         12
# 5                 2.1                   99                    400          2
# ...

# %%
df.loc[2,'region'] = ''

# %%
df.head()
# Out:
#   customer_id plan_type  data_usage_gb    region customer_tier  is_active  \
# 0        C001   Prepaid           12.5     North        Bronze          1
# 1        C002  Postpaid           45.1     South          Gold          1
# 2        C003   Prepaid            3.4  shravani        Silver          0
# 3        C004    Hybrid           22.3      West        Bronze          1
# 4        C005  Postpaid           55.8     North      Platinum          1
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 0           0         2025-01-12                         5               12.4
# 1           1         2025-01-01                        16                8.1
# 2           0         2024-12-28                        20                3.5
# 3           1         2025-01-10                         7               15.2
# 4           0         2025-01-14                         3                6.9
#
# ...

# %%
df.iloc[2]
# Out:
# customer_id                       C003
# plan_type                      Prepaid
# data_usage_gb                      3.4
# region                        shravani
# customer_tier                   Silver
# is_active                            0
# complaints                           0
# last_recharge_date          2024-12-28
# days_since_last_recharge            20
# avg_call_duration                  3.5
# min_monthly_payment                149
# total_recharge_amount              900
# sms_usage                            5
# churn                                1
# Name: 2, dtype: object

# %%
df.iloc[2,3]
# Out:
# 'shravani'

# %%
df.iloc[5,7]
# Out:
# '2024-12-20'

# %%
df.iloc[1:5]
# Out:
#   customer_id plan_type  data_usage_gb    region customer_tier  is_active  \
# 1        C002  Postpaid           45.1     South          Gold          1
# 2        C003   Prepaid            3.4  shravani        Silver          0
# 3        C004    Hybrid           22.3      West        Bronze          1
# 4        C005  Postpaid           55.8     North      Platinum          1
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 1           1         2025-01-01                        16                8.1
# 2           0         2024-12-28                        20                3.5
# 3           1         2025-01-10                         7               15.2
# 4           0         2025-01-14                         3                6.9
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# 1                  499                   5200         12      0
# 2                  149                    900          5      1
# ...

# %%
df.iloc[1:5,1:2]
# Out:
#   plan_type
# 1  Postpaid
# 2   Prepaid
# 3    Hybrid
# 4  Postpaid

# %%
df[['region','plan_type']]
# Out:
#       region plan_type
# 0      North   Prepaid
# 1      South  Postpaid
# 2   shravani   Prepaid
# 3       West    Hybrid
# 4      North  Postpaid
# 5      South   Prepaid
# 6       East  Postpaid
# 7       West    Hybrid
# 8      North   Prepaid
# 9      South  Postpaid
# 10      East    Hybrid
# 11      West   Prepaid
# 12     North  Postpaid
# 13     South    Hybrid
# 14      East   Prepaid

# %%
df.columns
# Out:
# Index(['customer_id', 'plan_type', 'data_usage_gb', 'region', 'customer_tier',
#        'is_active', 'complaints', 'last_recharge_date',
#        'days_since_last_recharge', 'avg_call_duration', 'min_monthly_payment',
#        'total_recharge_amount', 'sms_usage', 'churn'],
#       dtype='object')

# %%
df.isnull()
# Out:
#     customer_id  plan_type  data_usage_gb  region  customer_tier  is_active  \
# 0         False      False          False   False          False      False
# 1         False      False          False   False          False      False
# 2         False      False          False   False          False      False
# 3         False      False          False   False          False      False
# 4         False      False          False   False          False      False
# 5         False      False          False   False          False      False
# 6         False      False          False   False          False      False
# 7         False      False          False   False          False      False
# 8         False      False          False   False          False      False
# 9         False      False          False   False          False      False
# 10        False      False          False   False          False      False
# ...

# %%
df.loc

# %%
df.loc[2,'region'] = ''

# %%
df
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 1         C002  Postpaid           45.1  South          Gold          1
# 2         C003   Prepaid            3.4               Silver          0
# 3         C004    Hybrid           22.3   West        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 5         C006   Prepaid            8.9  South        Bronze          0
# 6         C007  Postpaid           33.5   East        Silver          1
# 7         C008    Hybrid           18.4   West        Silver          1
# 8         C009   Prepaid            6.1  North        Bronze          0
# 9         C010  Postpaid           47.0  South          Gold          1
# 10        C011    Hybrid           20.2   East        Silver          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# ...

# %%
df.isnull()
# Out:
#     customer_id  plan_type  data_usage_gb  region  customer_tier  is_active  \
# 0         False      False          False   False          False      False
# 1         False      False          False   False          False      False
# 2         False      False          False   False          False      False
# 3         False      False          False   False          False      False
# 4         False      False          False   False          False      False
# 5         False      False          False   False          False      False
# 6         False      False          False   False          False      False
# 7         False      False          False   False          False      False
# 8         False      False          False   False          False      False
# 9         False      False          False   False          False      False
# 10        False      False          False   False          False      False
# ...

# %%
df.loc[2,'region'] = 'south'

# %%
df
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 1         C002  Postpaid           45.1  South          Gold          1
# 2         C003   Prepaid            3.4  south        Silver          0
# 3         C004    Hybrid           22.3   West        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 5         C006   Prepaid            8.9  South        Bronze          0
# 6         C007  Postpaid           33.5   East        Silver          1
# 7         C008    Hybrid           18.4   West        Silver          1
# 8         C009   Prepaid            6.1  North        Bronze          0
# 9         C010  Postpaid           47.0  South          Gold          1
# 10        C011    Hybrid           20.2   East        Silver          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# ...

# %%
df.dropna()
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 1         C002  Postpaid           45.1  South          Gold          1
# 2         C003   Prepaid            3.4  south        Silver          0
# 3         C004    Hybrid           22.3   West        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 5         C006   Prepaid            8.9  South        Bronze          0
# 6         C007  Postpaid           33.5   East        Silver          1
# 7         C008    Hybrid           18.4   West        Silver          1
# 8         C009   Prepaid            6.1  North        Bronze          0
# 9         C010  Postpaid           47.0  South          Gold          1
# 10        C011    Hybrid           20.2   East        Silver          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# ...

# %%
df.loc[2:3]
# Out:
#   customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 2        C003   Prepaid            3.4  south        Silver          0
# 3        C004    Hybrid           22.3   West        Bronze          1
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 2           0         2024-12-28                        20                3.5
# 3           1         2025-01-10                         7               15.2
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# 2                  149                    900          5      1
# 3                  299                   2400         18      0

# %%
df.loc[:,"region"]
# Out:
# 0     North
# 1     South
# 2     south
# 3      West
# 4     North
# 5     South
# 6      East
# 7      West
# 8     North
# 9     South
# 10     East
# 11     West
# 12    North
# 13    South
# 14     East
# Name: region, dtype: object

# %%
df.loc[2]
# Out:
# customer_id                       C003
# plan_type                      Prepaid
# data_usage_gb                      3.4
# region                           south
# customer_tier                   Silver
# is_active                            0
# complaints                           0
# last_recharge_date          2024-12-28
# days_since_last_recharge            20
# avg_call_duration                  3.5
# min_monthly_payment                149
# total_recharge_amount              900
# sms_usage                            5
# churn                                1
# Name: 2, dtype: object

# %%
df.loc[2,"region"]
# Out:
# 'south'

# %%
df.loc[2:5]
# Out:
#   customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 2        C003   Prepaid            3.4  south        Silver          0
# 3        C004    Hybrid           22.3   West        Bronze          1
# 4        C005  Postpaid           55.8  North      Platinum          1
# 5        C006   Prepaid            8.9  South        Bronze          0
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 2           0         2024-12-28                        20                3.5
# 3           1         2025-01-10                         7               15.2
# 4           0         2025-01-14                         3                6.9
# 5           1         2024-12-20                        28                2.1
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# 2                  149                    900          5      1
# 3                  299                   2400         18      0
# ...

# %%
df.loc[2:5,"region"]
# Out:
# 2    south
# 3     West
# 4    North
# 5    South
# Name: region, dtype: object

# %%
df.loc[4:9,['region','plan_type']]
# Out:
#   region plan_type
# 4  North  Postpaid
# 5  South   Prepaid
# 6   East  Postpaid
# 7   West    Hybrid
# 8  North   Prepaid
# 9  South  Postpaid

# %%
df.loc[5]
# Out:
# customer_id                       C006
# plan_type                      Prepaid
# data_usage_gb                      8.9
# region                           South
# customer_tier                   Bronze
# is_active                            0
# complaints                           1
# last_recharge_date          2024-12-20
# days_since_last_recharge            28
# avg_call_duration                  2.1
# min_monthly_payment                 99
# total_recharge_amount              400
# sms_usage                            2
# churn                                1
# Name: 5, dtype: object

# %%
df.loc[4:10,['plan_type','region']]
# Out:
#    plan_type region
# 4   Postpaid  North
# 5    Prepaid  South
# 6   Postpaid   East
# 7     Hybrid   West
# 8    Prepaid  North
# 9   Postpaid  South
# 10    Hybrid   East

# %%
df.loc[:,"region"]
# Out:
# 0     North
# 1     South
# 2     south
# 3      West
# 4     North
# 5     South
# 6      East
# 7      West
# 8     North
# 9     South
# 10     East
# 11     West
# 12    North
# 13    South
# 14     East
# Name: region, dtype: object

# %%
df.loc[df["region"] == "North"]
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 8         C009   Prepaid            6.1  North        Bronze          0
# 12        C013  Postpaid           60.4  North      Platinum          1
#
#     complaints last_recharge_date  days_since_last_recharge  \
# 0            0         2025-01-12                         5
# 4            0         2025-01-14                         3
# 8            1         2024-12-18                        30
# 12           0         2025-01-15                         2
#
#     avg_call_duration  min_monthly_payment  total_recharge_amount  sms_usage  \
# 0                12.4                  199                   1500         34
# 4                 6.9                  799                   7000          8
# ...

# %%
df.loc[df['region'] == 'south']
# Out:
#   customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 2        C003   Prepaid            3.4  south        Silver          0
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 2           0         2024-12-28                        20                3.5
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# 2                  149                    900          5      1

# %%
df.loc[2,'region'] = 'qwert'

# %%
df.head()
# Out:
#   customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0        C001   Prepaid           12.5  North        Bronze          1
# 1        C002  Postpaid           45.1  South          Gold          1
# 2        C003   Prepaid            3.4  qwert        Silver          0
# 3        C004    Hybrid           22.3   West        Bronze          1
# 4        C005  Postpaid           55.8  North      Platinum          1
#
#    complaints last_recharge_date  days_since_last_recharge  avg_call_duration  \
# 0           0         2025-01-12                         5               12.4
# 1           1         2025-01-01                        16                8.1
# 2           0         2024-12-28                        20                3.5
# 3           1         2025-01-10                         7               15.2
# 4           0         2025-01-14                         3                6.9
#
#    min_monthly_payment  total_recharge_amount  sms_usage  churn
# ...

# %%
df.loc[df['data_usage_gb'] > 10]
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 0         C001   Prepaid           12.5  North        Bronze          1
# 1         C002  Postpaid           45.1  South          Gold          1
# 3         C004    Hybrid           22.3   West        Bronze          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 6         C007  Postpaid           33.5   East        Silver          1
# 7         C008    Hybrid           18.4   West        Silver          1
# 9         C010  Postpaid           47.0  South          Gold          1
# 10        C011    Hybrid           20.2   East        Silver          0
# 12        C013  Postpaid           60.4  North      Platinum          1
# 13        C014    Hybrid           15.5  South          Gold          0
#
#     complaints last_recharge_date  days_since_last_recharge  \
# 0            0         2025-01-12                         5
# ...

# %%
df.loc[df['data_usage_gb'] < 10]
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 2         C003   Prepaid            3.4  qwert        Silver          0
# 5         C006   Prepaid            8.9  South        Bronze          0
# 8         C009   Prepaid            6.1  North        Bronze          0
# 11        C012   Prepaid            4.8   West        Bronze          1
# 14        C015   Prepaid            2.3   East        Bronze          0
#
#     complaints last_recharge_date  days_since_last_recharge  \
# 2            0         2024-12-28                        20
# 5            1         2024-12-20                        28
# 8            1         2024-12-18                        30
# 11           0         2025-01-09                         8
# 14           1         2024-12-15                        33
#
#     avg_call_duration  min_monthly_payment  total_recharge_amount  sms_usage  \
# 2                 3.5                  149                    900          5
# ...

# %%
df.loc[df['plan_type' ] == 'Postpaid']
# Out:
#    customer_id plan_type  data_usage_gb region customer_tier  is_active  \
# 1         C002  Postpaid           45.1  South          Gold          1
# 4         C005  Postpaid           55.8  North      Platinum          1
# 6         C007  Postpaid           33.5   East        Silver          1
# 9         C010  Postpaid           47.0  South          Gold          1
# 12        C013  Postpaid           60.4  North      Platinum          1
#
#     complaints last_recharge_date  days_since_last_recharge  \
# 1            1         2025-01-01                        16
# 4            0         2025-01-14                         3
# 6            0         2025-01-16                         1
# 9            0         2025-01-13                         4
# 12           0         2025-01-15                         2
#
#     avg_call_duration  min_monthly_payment  total_recharge_amount  sms_usage  \
# 1                 8.1                  499                   5200         12
# ...

# %%
df.loc[df['plan_type'] == 'Postpaid','customer_tier']
# Out:
# 1         Gold
# 4     Platinum
# 6       Silver
# 9         Gold
# 12    Platinum
# Name: customer_tier, dtype: object

# %%
df.loc[
