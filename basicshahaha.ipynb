# %% [markdown]
# # Headings

# %% [markdown]
# # hell
# ## hell
# ### hell
# #### hell
# ##### hell
# ###### hell

# %% [markdown]
# # Fonts

# %% [markdown]
# *hell*
# **hell**
# ***hell***
# ~~HELL~~

# %% [markdown]
# # List

# %% [markdown]
# - YESS
# - Yess
# - yess
#   - HELL
#      - Hell
#      - hell
#           - hell

# %% [markdown]
# # HyperLinks

# %% [markdown]
# [D.G.Ruparel]_(https://www.ruparel.edu)

# %% [markdown]
# # TABLE

# %% [markdown]
# | NAME | AGE | COUNTRY | GENDER |
# |:----:|:----|--------:|--|
# |Parth |18   | India   | Male   |
# |Yash  |18   |India    | Male   |

# %% [markdown]
# # BlockQuotes

# %% [markdown]
# > BLOCK
# >>- BLOCK 2
# >>>> BLOCK 3

# %% [markdown]
# # Backtick

# %% [markdown]
# ```Python
# print("Hello world")
# ```

# %% [markdown]
# ```sql
# SELECT * FROM users;
# ```

# %% [markdown]
# ```bash
# is -1
# ```

# %% [markdown]
# # HORIZONTAL LINE

# %% [markdown]
# ---
# OR
# ***

# %% [markdown]
# # Escaping Special Characters

# %% [markdown]
# \#HEll
